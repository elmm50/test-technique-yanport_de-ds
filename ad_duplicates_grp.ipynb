# %% [markdown]
# # **Packages**

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans
# PCA
from sklearn.decomposition import PCA
# Normalisation
from sklearn.preprocessing import StandardScaler
# Hierarchical clustering
import scipy.cluster.hierarchy as sch
from sklearn.cluster import AgglomerativeClustering
# On hot encoding
from sklearn.preprocessing import OneHotEncoder
from sklearn.compose import ColumnTransformer
# date
from datetime import datetime

import seaborn as sns
import scipy.cluster.hierarchy as sch




from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"

# %% [markdown]
# # **Data Preparation**

# %% [markdown]
# Importer le jeu de données

# %%
data_set = pd.read_csv("/content/Dataset - Ads _ Levallois-Perret - 2019-08 - export-ads-levallois-perret-2019-08-27.csv")

# %% [markdown]
# Afficher le jeu de données

# %%
data_set.head(1)
# Out:
#                                      ID  \
# 0  22c05930-0eb5-11e7-b53d-bbead8ba43fe
#
#                                                  URL      CRAWL_SOURCE  \
# 0  http://www.avendrealouer.fr/location/levallois...  A_VENDRE_A_LOUER
#
#   PROPERTY_TYPE NEW_BUILD                                        DESCRIPTION  \
# 0     APARTMENT     False  Au rez de chaussée d'un bel immeuble récent,ap...
#
#                                               IMAGES  SURFACE  LAND_SURFACE  \
# 0  ["https://cf-medias.avendrealouer.fr/image/_87...     72.0           NaN
#
#    BALCONY_SURFACE  ...           DEALER_NAME  DEALER_TYPE   CITY_ID  \
# 0              NaN  ...  Lamirand Et Associes       AGENCY  54178039
#
#                CITY  ZIP_CODE  DEPT_CODE   PUBLICATION_START_DATE  \
# 0  Levallois-Perret   92300.0         92  2017-03-22T04:07:56.095
#
#    PUBLICATION_END_DATE          LAST_CRAWL_DATE  LAST_PRICE_DECREASE_DATE
# 0                   NaN  2017-04-21T18:52:35.733                       NaN
#
# [1 rows x 57 columns]

# %% [markdown]
# Afficher la taille du jeu de donées

# %%
data_set.shape
# Out:
# (2164, 57)

# %% [markdown]
# Afficher les colonnes du jeu de données

# %%
data_set.columns
# Out:
# Index(['ID', 'URL', 'CRAWL_SOURCE', 'PROPERTY_TYPE', 'NEW_BUILD',
#        'DESCRIPTION', 'IMAGES', 'SURFACE', 'LAND_SURFACE', 'BALCONY_SURFACE',
#        'TERRACE_SURFACE', 'ROOM_COUNT', 'BEDROOM_COUNT', 'BATHROOM_COUNT',
#        'LUNCHROOM_COUNT', 'TOILET_COUNT', 'FURNISHED', 'FIREPLACE',
#        'AIR_CONDITIONING', 'GARDEN', 'SWIMMING_POOL', 'BALCONY', 'TERRACE',
#        'CELLAR', 'PARKING', 'PARKING_COUNT', 'HEATING_TYPES', 'HEATING_MODE',
#        'FLOOR', 'FLOOR_COUNT', 'CONSTRUCTION_YEAR', 'ELEVATOR', 'CARETAKER',
#        'ENERGY_CONSUMPTION', 'GREENHOUSE_GAS_CONSUMPTION', 'MARKETING_TYPE',
#        'PRICE', 'PRICE_M2', 'PRICE_EVENTS', 'RENTAL_EXPENSES',
#        'RENTAL_EXPENSES_INCLUDED', 'DEPOSIT', 'FEES', 'FEES_INCLUDED',
#        'EXCLUSIVE_MANDATE', 'AGENCIES_UNWANTED', 'OCCUPIED', 'DEALER_NAME',
#        'DEALER_TYPE', 'CITY_ID', 'CITY', 'ZIP_CODE', 'DEPT_CODE',
#        'PUBLICATION_START_DATE', 'PUBLICATION_END_DATE', 'LAST_CRAWL_DATE',
#        'LAST_PRICE_DECREASE_DATE'],
#       dtype='object')

# %% [markdown]
# Afficher les informations sur chaque colonne

# %%
data_set.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2164 entries, 0 to 2163
# Data columns (total 57 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   ID                          2164 non-null   object
#  1   URL                         2164 non-null   object
#  2   CRAWL_SOURCE                2164 non-null   object
#  3   PROPERTY_TYPE               2164 non-null   object
#  4   NEW_BUILD                   1973 non-null   object
#  5   DESCRIPTION                 2160 non-null   object
#  6   IMAGES                      2164 non-null   object
#  7   SURFACE                     2050 non-null   float64
#  8   LAND_SURFACE                3 non-null      float64
#  9   BALCONY_SURFACE             0 non-null      float64
#  10  TERRACE_SURFACE             25 non-null     float64
#  11  ROOM_COUNT                  1835 non-null   float64
#  12  BEDROOM_COUNT               696 non-null    float64
#  13  BATHROOM_COUNT              0 non-null      float64
#  14  LUNCHROOM_COUNT             0 non-null      float64
#  15  TOILET_COUNT                0 non-null      float64
#  16  FURNISHED                   467 non-null    object
#  17  FIREPLACE                   0 non-null      float64
#  18  AIR_CONDITIONING            0 non-null      float64
#  19  GARDEN                      14 non-null     float64
#  20  SWIMMING_POOL               6 non-null      float64
#  21  BALCONY                     0 non-null      float64
#  22  TERRACE                     86 non-null     float64
#  23  CELLAR                      0 non-null      float64
#  24  PARKING                     2164 non-null   bool
#  25  PARKING_COUNT               157 non-null    float64
#  26  HEATING_TYPES               2164 non-null   object
#  27  HEATING_MODE                653 non-null    object
#  28  FLOOR                       660 non-null    float64
#  29  FLOOR_COUNT                 465 non-null    float64
#  30  CONSTRUCTION_YEAR           503 non-null    float64
#  31  ELEVATOR                    552 non-null    object
#  32  CARETAKER                   247 non-null    object
#  33  ENERGY_CONSUMPTION          0 non-null      float64
#  34  GREENHOUSE_GAS_CONSUMPTION  0 non-null      float64
#  35  MARKETING_TYPE              2164 non-null   object
#  36  PRICE                       2104 non-null   float64
#  37  PRICE_M2                    1991 non-null   float64
#  38  PRICE_EVENTS                2164 non-null   object
#  39  RENTAL_EXPENSES             441 non-null    float64
#  40  RENTAL_EXPENSES_INCLUDED    600 non-null    object
#  41  DEPOSIT                     55 non-null     float64
#  42  FEES                        94 non-null     float64
#  43  FEES_INCLUDED               511 non-null    object
#  44  EXCLUSIVE_MANDATE           2164 non-null   bool
#  45  AGENCIES_UNWANTED           201 non-null    object
#  46  OCCUPIED                    1209 non-null   object
#  47  DEALER_NAME                 2077 non-null   object
#  48  DEALER_TYPE                 2164 non-null   object
#  49  CITY_ID                     2164 non-null   int64
#  50  CITY                        2164 non-null   object
#  51  ZIP_CODE                    2163 non-null   float64
#  52  DEPT_CODE                   2164 non-null   int64
#  53  PUBLICATION_START_DATE      2164 non-null   object
#  54  PUBLICATION_END_DATE        0 non-null      float64
#  55  LAST_CRAWL_DATE             2164 non-null   object
#  56  LAST_PRICE_DECREASE_DATE    340 non-null    object
# dtypes: bool(2), float64(29), int64(2), object(24)
# memory usage: 934.2+ KB

# %% [markdown]
# Voir les colonnes qui contient le plus de NaN, pour le supprimer ensuite

# %%
data_set.isnull().sum()
# Out:
# ID                               0
# URL                              0
# CRAWL_SOURCE                     0
# PROPERTY_TYPE                    0
# NEW_BUILD                      191
# DESCRIPTION                      4
# IMAGES                           0
# SURFACE                        114
# LAND_SURFACE                  2161
# BALCONY_SURFACE               2164
# TERRACE_SURFACE               2139
# ROOM_COUNT                     329
# BEDROOM_COUNT                 1468
# BATHROOM_COUNT                2164
# LUNCHROOM_COUNT               2164
# TOILET_COUNT                  2164
# FURNISHED                     1697
# FIREPLACE                     2164
# AIR_CONDITIONING              2164
# GARDEN                        2150
# SWIMMING_POOL                 2158
# BALCONY                       2164
# TERRACE                       2078
# CELLAR                        2164
# PARKING                          0
# PARKING_COUNT                 2007
# HEATING_TYPES                    0
# HEATING_MODE                  1511
# FLOOR                         1504
# FLOOR_COUNT                   1699
# CONSTRUCTION_YEAR             1661
# ELEVATOR                      1612
# CARETAKER                     1917
# ENERGY_CONSUMPTION            2164
# GREENHOUSE_GAS_CONSUMPTION    2164
# MARKETING_TYPE                   0
# PRICE                           60
# PRICE_M2                       173
# PRICE_EVENTS                     0
# RENTAL_EXPENSES               1723
# RENTAL_EXPENSES_INCLUDED      1564
# DEPOSIT                       2109
# FEES                          2070
# FEES_INCLUDED                 1653
# EXCLUSIVE_MANDATE                0
# AGENCIES_UNWANTED             1963
# OCCUPIED                       955
# DEALER_NAME                     87
# DEALER_TYPE                      0
# CITY_ID                          0
# CITY                             0
# ZIP_CODE                         1
# DEPT_CODE                        0
# PUBLICATION_START_DATE           0
# PUBLICATION_END_DATE          2164
# LAST_CRAWL_DATE                  0
# LAST_PRICE_DECREASE_DATE      1824
# dtype: int64

# %% [markdown]
# # Méthodologie de regroupement

# %% [markdown]
# Après étude de la base de données, on constate qu'il y'a une colonne "PROPERTY_TYPE" a cinq possibilités :

# %%
data_set["PROPERTY_TYPE"].unique()
# Out:
# array(['APARTMENT', 'PREMISES', 'HOUSE', 'PARKING', 'BUILDING'],
#       dtype=object)

# %% [markdown]
# On constate aussi qu'il y'a une colonne "EXCLUSIVE_MANDATE", qui signifique que le proprietaire du bien immobilier a donner droit a un seul et unique agent immobilier de publie son bien immobilier, ainsi on peut par cette classification resortir les outliers.

# %%
data_set["EXCLUSIVE_MANDATE"].unique()
# Out:
# array([False,  True])

# %% [markdown]
# Comme on veut regrouper les annonces, avoir un data set petit nous facilite de regrouper les annonces suivant leurs similarites, donc notre méthodologie sera la suivant :
#
# 1. Diviser le data set en 5 parties suivant le type de la propriete noté par exemple dataset_P
#
# 2. Diviser chaque dataset_P en deux, suivant le type EXCLUSIVE_MANDATE, avec si s'est vrai nous permet de resortir directement l'annocne(pas toujours mais mieux) unique du bien immobilier.

# %%
### Apartment
data_apar = data_set[data_set["PROPERTY_TYPE"] == 'APARTMENT']
data_apar_ex = data_apar[data_apar["EXCLUSIVE_MANDATE"] == True]       # Si EXCLUSIVE_MANDATE est bien signé
data_apar_no_ex = data_apar[data_apar["EXCLUSIVE_MANDATE"] == False]   # Si EXCLUSIVE_MANDATE non signé

# Taille
data_apar.shape
data_apar_ex.shape
data_apar_no_ex.shape
# Out:
# (1436, 57)
# (135, 57)
# (1301, 57)

# %%
### Premises
data_pre = data_set[data_set["PROPERTY_TYPE"] == 'PREMISES']
data_pre_ex = data_pre[data_pre["EXCLUSIVE_MANDATE"] == True]       # Si EXCLUSIVE_MANDATE est bien signé
data_pre_no_ex = data_pre[data_pre["EXCLUSIVE_MANDATE"] == False]   # Si EXCLUSIVE_MANDATE non signé

# Taille
data_pre.shape
data_pre_ex.shape
data_pre_no_ex.shape
# Out:
# (479, 57)
# (22, 57)
# (457, 57)

# %%
###  House
data_hou = data_set[data_set["PROPERTY_TYPE"] == 'HOUSE']
data_hou_ex = data_hou[data_hou["EXCLUSIVE_MANDATE"] == True]       # Si EXCLUSIVE_MANDATE est bien signé
data_hou_no_ex = data_hou[data_hou["EXCLUSIVE_MANDATE"] == False]   # Si EXCLUSIVE_MANDATE non signé

# Taille
data_hou.shape
data_hou_ex.shape
data_hou_no_ex.shape
# Out:
# (52, 57)
# (2, 57)
# (50, 57)

# %%
### Parking
data_par = data_set[data_set["PROPERTY_TYPE"] == 'PARKING']
data_par_ex = data_par[data_par["EXCLUSIVE_MANDATE"] == True]       # Si EXCLUSIVE_MANDATE est bien signé
data_par_no_ex = data_par[data_par["EXCLUSIVE_MANDATE"] == False]   # Si EXCLUSIVE_MANDATE non signé

# Taille
data_par.shape
data_par_ex.shape
data_par_no_ex.shape
# Out:
# (188, 57)
# (8, 57)
# (180, 57)

# %%
### Building
data_bui = data_set[data_set["PROPERTY_TYPE"] == 'BUILDING']
data_bui_ex = data_bui[data_bui["EXCLUSIVE_MANDATE"] == True]       # Si EXCLUSIVE_MANDATE est bien signé
data_bui_no_ex = data_bui[data_bui["EXCLUSIVE_MANDATE"] == False]   # Si EXCLUSIVE_MANDATE non signé

# Taille
data_bui.shape
data_bui_ex.shape
data_bui_no_ex.shape
# Out:
# (9, 57)
# (0, 57)
# (9, 57)

# %% [markdown]
# On constate bien qu'il y'a une énorme difference de taille, se qui nous aidera pour regrouper efficacement

# %% [markdown]
# # **Exploratory Data Analysis and Building Model**

# %% [markdown]
# ### On commence par data_bui :

# %%
data_bui_ex  # Vide
# Out:
# Empty DataFrame
# Columns: [ID, URL, CRAWL_SOURCE, PROPERTY_TYPE, NEW_BUILD, DESCRIPTION, IMAGES, SURFACE, LAND_SURFACE, BALCONY_SURFACE, TERRACE_SURFACE, ROOM_COUNT, BEDROOM_COUNT, BATHROOM_COUNT, LUNCHROOM_COUNT, TOILET_COUNT, FURNISHED, FIREPLACE, AIR_CONDITIONING, GARDEN, SWIMMING_POOL, BALCONY, TERRACE, CELLAR, PARKING, PARKING_COUNT, HEATING_TYPES, HEATING_MODE, FLOOR, FLOOR_COUNT, CONSTRUCTION_YEAR, ELEVATOR, CARETAKER, ENERGY_CONSUMPTION, GREENHOUSE_GAS_CONSUMPTION, MARKETING_TYPE, PRICE, PRICE_M2, PRICE_EVENTS, RENTAL_EXPENSES, RENTAL_EXPENSES_INCLUDED, DEPOSIT, FEES, FEES_INCLUDED, EXCLUSIVE_MANDATE, AGENCIES_UNWANTED, OCCUPIED, DEALER_NAME, DEALER_TYPE, CITY_ID, CITY, ZIP_CODE, DEPT_CODE, PUBLICATION_START_DATE, PUBLICATION_END_DATE, LAST_CRAWL_DATE, LAST_PRICE_DECREASE_DATE]
# Index: []
#
# [0 rows x 57 columns]

# %% [markdown]
# On connait que les biens immobilier sont dans la même ville, on supprime alors les colonnes CITY_ID, CITY, ZIP_CODE, DEPT_CODE.
#
# Comme on veut regroupe par rapport aux caracteristiques d'un bien et non par rapport au nom de l'agence et nom du site d'annonces et les caracteritiques de ses dernieres et d'après la commande precedent, on a des colonnes vide.
#
# On conclue qu'on va garder que les colonnes suivents :

# %%
data_bui_no_ex_grp = data_bui_no_ex[['PRICE','PRICE_M2','SURFACE']]
data_bui_no_ex_grp

# %% [markdown]
# On a pas besoin de Machine learning pour regroupe ces annonces par rapport à un bien immobilier puisque qu'ils sont uniques, ainsi on a :

# %%
data_bui_no_ex_grp

# %% [markdown]
#  ### On passe a data_par :

# %%
data_par_ex
# Out:
#                                         ID  \
# 358   d0ad6680-4ae2-11e9-ba7a-0ff7ef4fe44b
# 1213  760ec980-b7f2-11e9-9fab-c3006e339e11
# 1554  e7309d90-1ece-11e9-8321-1350c9447565
# 1613  4b83fb00-ae78-11e9-81e9-5f24299f2ef3
# 1731  a7589690-5afc-11e9-adc1-59e67c527828
# 1773  c1ba9cb0-5730-11e9-bcf5-3b398c242d19
# 1930  eb8cee30-4b41-11e9-ba7a-0ff7ef4fe44b
# 2162  8cba88c0-a07a-11e9-a8e6-0de7b497e456
#
#                                                     URL CRAWL_SOURCE  \
# 358   http://www.logic-immo.com/detail-vente-aa9864c...   LOGIC_IMMO
# 1213  https://www.paruvendu.fr/immobilier/location/p...   PARU_VENDU
# 1554  https://www.logic-immo.com/detail-location-f2d...   LOGIC_IMMO
# 1613  https://www.logic-immo.com/detail-location-96d...   LOGIC_IMMO
# 1731  https://www.seloger.com/annonces/achat/parking...     SE_LOGER
# 1773  https://www.seloger.com/annonces/achat/parking...     SE_LOGER
# 1930  https://immobilier.lefigaro.fr/annonces/annonc...   EXPLORIMMO
# 2162  https://www.logic-immo.com/detail-location-bae...   LOGIC_IMMO
#
#      PROPERTY_TYPE NEW_BUILD  \
# 358        PARKING       NaN
# 1213       PARKING       NaN
# 1554       PARKING       NaN
# 1613       PARKING       NaN
# 1731       PARKING       NaN
# 1773       PARKING       NaN
# 1930       PARKING       NaN
# 2162       PARKING       NaN
#
#                                             DESCRIPTION  \
# 358   LEVALLOIS Parc de la Planchette - Dans une rés...
# 1213  85 rue edouard vaillant, levallois perret, MAN...
# 1554  Place de parking à louer au 2 rue Maurice Rave...
# 1613  Rue Jules Guesde emplacement Parking au1 er so...
# 1731  Levallois • So Ouest • Parking • Exclusivité. ...
# 1773  En exclusivité dans votre agence ERA Levallois...
# 1930  Levallois - So Ouest - Parking - Exclusivité. ...
# 2162  Levallois-Perret, rue Paul Vaillant Couturier,...
#
#                                                  IMAGES  SURFACE  \
# 358   ["https://mmf.logic-immo.com/mmf/ads/photo-pro...     15.0
# 1213  ["https://media.paruvendu.fr/media_ext/photo3....      NaN
# 1554  ["https://mmf.logic-immo.com/mmf/ads/photo-pro...     17.0
# 1613  ["https://mmf.logic-immo.com/mmf/ads/photo-pro...      NaN
# 1731  ["https://v.seloger.com/s/width/800/visuels/0/...      NaN
# 1773  ["https://pix.yanport.com/ads/c1ba9cb0-5730-11...      NaN
# 1930  ["https://thbr.figarocms.net/images/8eX8P9teA8...      NaN
# 2162  ["https://mmf.logic-immo.com/mmf/ads/photo-pro...      NaN
#
#       LAND_SURFACE  BALCONY_SURFACE  ...                 DEALER_NAME  \
# 358            NaN              NaN  ...                Ouest Avenue
# 1213           NaN              NaN  ...             Groupe Babylone
# 1554           NaN              NaN  ...                     yespark
# 1613           NaN              NaN  ...             GROUPE SOGESTIM
# 1731           NaN              NaN  ...          Bosetta Immobilier
# 1773           NaN              NaN  ...    Era Immobilier Levallois
# 1930           NaN              NaN  ...          Bosetta Immobilier
# 2162           NaN              NaN  ...  Nicolas Lanteri Immobilier
#
#       DEALER_TYPE   CITY_ID              CITY  ZIP_CODE  DEPT_CODE  \
# 358        AGENCY  54178039  Levallois-Perret   92300.0         92
# 1213       AGENCY  54178039  Levallois-Perret   92300.0         92
# 1554       AGENCY  54178039  Levallois-Perret   92300.0         92
# 1613       AGENCY  54178039  Levallois-Perret   92300.0         92
# 1731       AGENCY  54178039  Levallois-Perret   92300.0         92
# 1773       AGENCY  54178039  Levallois-Perret   92300.0         92
# 1930       AGENCY  54178039  Levallois-Perret   92300.0         92
# 2162       AGENCY  54178039  Levallois-Perret   92300.0         92
#
#        PUBLICATION_START_DATE  PUBLICATION_END_DATE          LAST_CRAWL_DATE  \
# 358     2019-03-20T07:36:02.5                   NaN  2019-05-19T07:11:08.006
# 1213  2019-08-06T02:32:38.337                   NaN  2019-08-13T04:46:38.928
# 1554  2019-01-23T05:22:36.476                   NaN   2019-08-07T21:30:11.93
# 1613  2019-07-25T01:05:25.204                   NaN  2019-08-16T18:52:36.285
# 1731  2019-03-20T16:20:23.286                   NaN  2019-08-08T18:00:13.446
# 1773  2019-04-04T23:24:11.983                   NaN  2019-08-25T19:11:30.302
# 1930  2019-03-20T18:56:48.789                   NaN  2019-08-13T03:58:21.878
# 2162  2019-07-06T10:07:45.114                   NaN  2019-08-27T11:53:04.317
#
#       LAST_PRICE_DECREASE_DATE
# 358                 2019-05-19
# 1213                       NaN
# 1554                       NaN
# 1613                       NaN
# 1731                       NaN
# 1773                2019-06-25
# 1930                       NaN
# 2162                       NaN
#
# [8 rows x 57 columns]

# %% [markdown]
# De la même maniere on a ci-dessus les biens immobilers uniques

# %%
#
data_par_no_ex_grp = data_par_no_ex[['PRICE_M2','SURFACE','PRICE']]
data_par_no_ex_grp = data_par_no_ex_grp.dropna()

# Perform DBSCAN clustering
from sklearn.cluster import DBSCAN

dbscan = DBSCAN(eps=1, min_samples=2)
data_par_no_ex_grp['Cluster'] = dbscan.fit_predict(data_par_no_ex_grp)

# Display the clusters
unique_clusters = data_par_no_ex_grp['Cluster'].unique()
for cluster_num in unique_clusters:
    if cluster_num == -1:  # Cluster -1 represents noisy points
        continue
    cluster_data = data_par_no_ex_grp[data_par_no_ex_grp['Cluster'] == cluster_num]
    print(f'Cluster {cluster_num}:')
    print(cluster_data)
# Out:
# Cluster 0:
#       PRICE_M2  SURFACE  PRICE  Cluster
# 8         9.09     11.0  100.0        0
# 1487      9.09     11.0  100.0        0
# Cluster 1:
#       PRICE_M2  SURFACE  PRICE  Cluster
# 27        10.0     10.0  100.0        1
# 710       10.0     10.0  100.0        1
# 1100      10.0     10.0  100.0        1
# 1359      10.0     10.0  100.0        1
# 1463      10.0     10.0  100.0        1
# 1941      10.0     10.0  100.0        1
# Cluster 2:
#       PRICE_M2  SURFACE  PRICE  Cluster
# 33        8.33     12.0  100.0        2
# 440       8.33     12.0  100.0        2
# 500       8.33     12.0  100.0        2
# 1099      8.33     12.0  100.0        2
# Cluster 3:
#       PRICE_M2  SURFACE  PRICE  Cluster
# 43        14.4     10.0  144.0        3
# 788       14.4     10.0  144.0        3
# 1634      14.4     10.0  144.0        3
# Cluster 4:
#      PRICE_M2  SURFACE    PRICE  Cluster
# 84     1600.0     15.0  24000.0        4
# 169    1600.0     15.0  24000.0        4
# Cluster 5:
#      PRICE_M2  SURFACE  PRICE  Cluster
# 110      6.82     11.0   75.0        5
# 360      6.82     11.0   75.0        5
# Cluster 6:
#      PRICE_M2  SURFACE    PRICE  Cluster
# 168    1750.0     12.0  21000.0        6
# 754    1750.0     12.0  21000.0        6
# Cluster 7:
#       PRICE_M2  SURFACE  PRICE  Cluster
# 177       9.17     12.0  110.0        7
# 419       9.17     12.0  110.0        7
# 976       9.17     12.0  110.0        7
# 1032      9.17     12.0  110.0        7
# 1159      9.17     12.0  110.0        7
# 1479      9.17     12.0  110.0        7
# 1553      9.17     12.0  110.0        7
# 2008      9.17     12.0  110.0        7
# Cluster 8:
#       PRICE_M2  SURFACE  PRICE  Cluster
# 182       9.40     13.3  125.0        8
# 188       8.93     14.0  125.0        8
# 1358      8.93     14.0  125.0        8
# 1589      8.93     14.0  125.0        8
# 1592      8.93     14.0  125.0        8
# Cluster 9:
#       PRICE_M2  SURFACE    PRICE  Cluster
# 232    3666.67     12.0  44000.0        9
# 586    3666.67     12.0  44000.0        9
# 1400   3666.67     12.0  44000.0        9
# Cluster 10:
#       PRICE_M2  SURFACE  PRICE  Cluster
# 373       15.0     10.0  150.0       10
# 811       15.0     10.0  150.0       10
# 1658      15.0     10.0  150.0       10
# Cluster 11:
#       PRICE_M2  SURFACE  PRICE  Cluster
# 380       10.2     10.0  102.0       11
# 1935      10.2     10.0  102.0       11
# Cluster 12:
#       PRICE_M2  SURFACE  PRICE  Cluster
# 405        8.0     15.0  120.0       12
# 1870       8.0     15.0  120.0       12
# Cluster 13:
#       PRICE_M2  SURFACE    PRICE  Cluster
# 407    2083.33     12.0  25000.0       13
# 465    2083.33     12.0  25000.0       13
# 1540   2083.33     12.0  25000.0       13
# 1646   2083.33     12.0  25000.0       13
# 1844   2083.33     12.0  25000.0       13
# 1859   2083.33     12.0  25000.0       13
# Cluster 14:
#      PRICE_M2  SURFACE    PRICE  Cluster
# 447   2916.67     12.0  35000.0       14
# 680   2916.67     12.0  35000.0       14
# 958   2916.67     12.0  35000.0       14
# Cluster 15:
#       PRICE_M2  SURFACE  PRICE  Cluster
# 715       10.0     12.0  120.0       15
# 1740      10.0     12.0  120.0       15
# 1916      10.0     12.0  120.0       15
# 1937      10.0     12.0  120.0       15
# Cluster 16:
#       PRICE_M2  SURFACE  PRICE  Cluster
# 843       12.0     10.0  120.0       16
# 1229      12.0     10.0  120.0       16
# Cluster 17:
#       PRICE_M2  SURFACE  PRICE  Cluster
# 1160      12.5     12.0  150.0       17
# 1552      12.5     12.0  150.0       17
# <ipython-input-62-d9289883ec27>:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_par_no_ex_grp['Cluster'] = dbscan.fit_predict(data_par_no_ex_grp)

# %% [markdown]
# On voit bien qu'on a les annonces bien grouper !

# %% [markdown]
# ### On passe a data_hou :

# %%
data_hou_ex

# %% [markdown]
# Pas besoin de regrouper

# %%
#
data_hou_no_ex_grp = data_hou_no_ex[['SURFACE','PRICE','PRICE_M2']]
data_hou_no_ex_grp = data_hou_no_ex_grp.dropna()

# Perform DBSCAN clustering
from sklearn.cluster import DBSCAN

dbscan = DBSCAN(eps=1, min_samples=2)
data_hou_no_ex_grp['Cluster'] = dbscan.fit_predict(data_hou_no_ex_grp)

# Display the clusters
unique_clusters = data_hou_no_ex_grp['Cluster'].unique()
for cluster_num in unique_clusters:
    if cluster_num == -1:  # Cluster -1 represents noisy points
        continue
    cluster_data = data_hou_no_ex_grp[data_hou_no_ex_grp['Cluster'] == cluster_num]
    print(f'Cluster {cluster_num}:')
    print(cluster_data)
# Out:
# Cluster 0:
#       SURFACE      PRICE  PRICE_M2  Cluster
# 4       330.0  2790000.0   8454.55        0
# 793     330.0  2790000.0   8454.55        0
# 1201    330.0  2790000.0   8454.55        0
# 1541    330.0  2790000.0   8454.55        0
# 1606    330.0  2790000.0   8454.55        0
# 1621    330.0  2790000.0   8454.55        0
# 1719    330.0  2790000.0   8454.55        0
# 1922    330.0  2790000.0   8454.55        0
# 1923    330.0  2790000.0   8454.55        0
# 1936    330.0  2790000.0   8454.55        0
# Cluster 1:
#      SURFACE   PRICE  PRICE_M2  Cluster
# 60      92.0  1890.0     20.54        1
# 603     92.0  1890.0     20.54        1
# Cluster 2:
#       SURFACE      PRICE  PRICE_M2  Cluster
# 74      127.0  1290000.0  10157.48        2
# 620     127.0  1290000.0  10157.48        2
# 944     127.0  1290000.0  10157.48        2
# 1031    127.0  1290000.0  10157.48        2
# 1230    127.0  1290000.0  10157.48        2
# 2134    127.0  1290000.0  10157.48        2
# Cluster 3:
#       SURFACE      PRICE  PRICE_M2  Cluster
# 242     290.0  3269000.0  11272.41        3
# 503     290.0  3269000.0  11272.41        3
# 561     290.0  3269000.0  11272.41        3
# 589     290.0  3269000.0  11272.41        3
# 1762    290.0  3269000.0  11272.41        3
# 2097    290.0  3269000.0  11272.41        3
# 2115    290.0  3269000.0  11272.41        3
# Cluster 4:
#      SURFACE     PRICE  PRICE_M2  Cluster
# 421    180.0  895000.0   4972.22        4
# 951    180.0  895000.0   4972.22        4
# Cluster 5:
#       SURFACE      PRICE  PRICE_M2  Cluster
# 446     423.0  3429000.0   8106.38        5
# 922     423.0  3429000.0   8106.38        5
# 1161    423.0  3429000.0   8106.38        5
# 2063    423.0  3429000.0   8106.38        5
# Cluster 6:
#       SURFACE   PRICE  PRICE_M2  Cluster
# 557     290.0  6000.0     20.69        6
# 880     290.0  6000.0     20.69        6
# 1404    290.0  6000.0     20.69        6
# 1423    290.0  6000.0     20.69        6
# Cluster 7:
#       SURFACE   PRICE  PRICE_M2  Cluster
# 748     280.0  6000.0     21.43        7
# 1154    280.0  6000.0     21.43        7

# %% [markdown]
# On a encore bien regrouper les annonces

# %% [markdown]
# ### On passe a data_pre :

# %%
#
data_pre_ex_grp = data_pre_ex[['SURFACE','PRICE_M2','PRICE']]
data_pre_ex_grp = data_pre_ex_grp.dropna()

# Perform DBSCAN clustering
from sklearn.cluster import DBSCAN

dbscan = DBSCAN(eps=1, min_samples=2)
data_pre_ex_grp['Cluster'] = dbscan.fit_predict(data_pre_ex_grp)

# Display the clusters
unique_clusters = data_pre_ex_grp['Cluster'].unique()
for cluster_num in unique_clusters:
    if cluster_num == -1:  # Cluster -1 represents noisy points
        continue
    cluster_data = data_pre_ex_grp[data_pre_ex_grp['Cluster'] == cluster_num]
    print(f'Cluster {cluster_num}:')
    print(cluster_data)
# Out:
# Cluster 0:
#      SURFACE  PRICE_M2    PRICE  Cluster
# 313     55.0   1603.64  88200.0        0
# 545     55.0   1603.64  88200.0        0
# Cluster 1:
#       SURFACE  PRICE_M2  PRICE  Cluster
# 839      53.0     14.15  750.0        1
# 1140     53.0     14.15  750.0        1

# %% [markdown]
# On a regroupe pas mal les annonces

# %%
#
data_pre_no_ex_grp = data_pre_no_ex[['SURFACE','PRICE','PRICE_M2']]
data_pre_no_ex_grp = data_pre_no_ex_grp.dropna()

# Perform DBSCAN clustering
from sklearn.cluster import DBSCAN

dbscan = DBSCAN(eps=1, min_samples=2)
data_pre_no_ex_grp['Cluster'] = dbscan.fit_predict(data_pre_no_ex_grp)

# Display the clusters
unique_clusters = data_pre_no_ex_grp['Cluster'].unique()
for cluster_num in unique_clusters:
    if cluster_num == -1:  # Cluster -1 represents noisy points
        continue
    cluster_data = data_pre_no_ex_grp[data_pre_no_ex_grp['Cluster'] == cluster_num]
    print(f'Cluster {cluster_num}:')
    print(cluster_data)

# %% [markdown]
# On voit qu'on a bien classer les annonces

# %% [markdown]
# ### On passe a data_apar :

# %%
#
data_apar_ex_grp = data_apar_ex[['SURFACE','PRICE_M2','PRICE']]
data_apar_ex_grp = data_apar_ex_grp.dropna()

# Perform DBSCAN clustering
from sklearn.cluster import DBSCAN

dbscan = DBSCAN(eps=1, min_samples=2)
data_apar_ex_grp['Cluster'] = dbscan.fit_predict(data_apar_ex_grp)

# Display the clusters
unique_clusters = data_apar_ex_grp['Cluster'].unique()
for cluster_num in unique_clusters:
    if cluster_num == -1:  # Cluster -1 represents noisy points
        continue
    cluster_data = data_apar_ex_grp[data_apar_ex_grp['Cluster'] == cluster_num]
    print(f'Cluster {cluster_num}:')
    print(cluster_data)
# Out:
# Cluster 0:
#       SURFACE  PRICE_M2      PRICE  Cluster
# 71       45.0  10111.12  455000.44        0
# 1869     45.0  10111.11  455000.00        0
# Cluster 1:
#      SURFACE  PRICE_M2     PRICE  Cluster
# 137     73.0  10602.74  774000.0        1
# 968     73.0  10602.74  774000.0        1
# Cluster 2:
#      SURFACE  PRICE_M2     PRICE  Cluster
# 139     55.0  10727.27  590000.0        2
# 615     55.0  10727.27  590000.0        2
# Cluster 3:
#       SURFACE  PRICE_M2     PRICE  Cluster
# 142     85.43  11260.68  962000.0        3
# 2137    85.43  11260.68  962000.0        3
# Cluster 4:
#       SURFACE  PRICE_M2      PRICE  Cluster
# 200      43.0    8581.4  369000.27        4
# 1374     43.0    8581.4  369000.00        4
# Cluster 5:
#      SURFACE  PRICE_M2      PRICE  Cluster
# 202    110.0  10090.91  1110000.0        5
# 612    110.0  10090.91  1110000.0        5
# 942    110.0  10090.91  1110000.0        5
# Cluster 6:
#       SURFACE  PRICE_M2      PRICE  Cluster
# 207     120.0    8575.0  1029000.0        6
# 1287    120.0    8575.0  1029000.0        6
# Cluster 7:
#      SURFACE  PRICE_M2      PRICE  Cluster
# 261     59.0  14220.34  839000.00        7
# 906     59.0  14220.34  838999.98        7
# Cluster 8:
#       SURFACE  PRICE_M2      PRICE  Cluster
# 286     120.0   9583.33  1150000.0        8
# 1623    120.0   9583.33  1150000.0        8
# 1780    120.0   9583.33  1150000.0        8
# 2101    120.0   9583.33  1150000.0        8
# Cluster 9:
#       SURFACE  PRICE_M2     PRICE  Cluster
# 289      85.0  11317.65  962000.0        9
# 697      85.0  11317.65  962000.0        9
# 1125     85.0  11317.65  962000.0        9
# Cluster 10:
#       SURFACE  PRICE_M2     PRICE  Cluster
# 297     50.38   9884.87  498000.0       10
# 646     50.38   9884.87  498000.0       10
# 2152    50.38   9884.87  498000.0       10
# Cluster 11:
#       SURFACE  PRICE_M2     PRICE  Cluster
# 300      87.0   7586.21  660000.0       11
# 1686     87.0   7586.21  660000.0       11
# 2021     87.0   7586.21  660000.0       11
# Cluster 12:
#       SURFACE  PRICE_M2      PRICE  Cluster
# 302     110.0   13000.0  1430000.0       12
# 1194    110.0   13000.0  1430000.0       12
# 1202    110.0   13000.0  1430000.0       12
# Cluster 13:
#       SURFACE  PRICE_M2     PRICE  Cluster
# 401      27.0  13259.26  358000.0       13
# 1713     27.0  13259.26  358000.0       13
# Cluster 14:
#       SURFACE  PRICE_M2      PRICE  Cluster
# 488     117.0   9401.71  1100000.0       14
# 1914    117.0   9401.71  1100000.0       14
# Cluster 15:
#      SURFACE  PRICE_M2     PRICE  Cluster
# 491     84.0   9940.48  835000.0       15
# 655     84.0   9940.48  835000.0       15
# 778     84.0   9940.48  835000.0       15
# Cluster 16:
#      SURFACE  PRICE_M2     PRICE  Cluster
# 516     40.0    9200.0  368000.0       16
# 796     40.0    9200.0  368000.0       16
# Cluster 17:
#       SURFACE  PRICE_M2      PRICE  Cluster
# 526     109.0   13394.5  1460000.0       17
# 1453    109.0   13394.5  1460000.0       17
# 2081    109.0   13394.5  1460000.0       17
# Cluster 18:
#       SURFACE  PRICE_M2   PRICE  Cluster
# 528      71.0     36.62  2600.0       18
# 1129     71.0     36.62  2600.0       18
# 1276     71.0     36.62  2600.0       18
# Cluster 19:
#       SURFACE  PRICE_M2     PRICE  Cluster
# 574      54.0   8518.52  460000.0       19
# 1521     54.0   8518.52  460000.0       19
# Cluster 20:
#       SURFACE  PRICE_M2     PRICE  Cluster
# 628      50.0    9960.0  498000.0       20
# 1456     50.0    9960.0  498000.0       20
# 1810     50.0    9960.0  498000.0       20
# Cluster 21:
#       SURFACE  PRICE_M2     PRICE  Cluster
# 716      46.7   9379.01  438000.0       21
# 1531     46.7   9379.01  438000.0       21
# Cluster 22:
#       SURFACE  PRICE_M2     PRICE  Cluster
# 741      30.0   11500.0  345000.0       22
# 758      30.0   11500.0  345000.0       22
# 1488     30.0   11500.0  345000.0       22
# Cluster 23:
#       SURFACE  PRICE_M2     PRICE  Cluster
# 783      52.0   9711.54  505000.0       23
# 2037     52.0   9711.54  505000.0       23
# Cluster 24:
#       SURFACE  PRICE_M2     PRICE  Cluster
# 883      37.0  10135.14  375000.0       24
# 1663     37.0  10135.14  375000.0       24
# Cluster 25:
#       SURFACE  PRICE_M2     PRICE  Cluster
# 1142     65.0   8446.15  549000.0       25
# 2090     65.0   8446.15  549000.0       25
# Cluster 26:
#       SURFACE  PRICE_M2     PRICE  Cluster
# 1261    29.68   9400.27  279000.0       26
# 2107    29.68   9400.27  279000.0       26
# Cluster 27:
#       SURFACE  PRICE_M2      PRICE  Cluster
# 1283    102.0  10421.57  1063000.0       27
# 1633    102.0  10421.57  1063000.0       27
# 1897    102.0  10421.57  1063000.0       27
# 1920    102.0  10421.57  1063000.0       27
# Cluster 28:
#       SURFACE  PRICE_M2     PRICE  Cluster
# 1518     31.0   9580.65  297000.0       28
# 1617     31.0   9580.65  297000.0       28
# Cluster 29:
#       SURFACE  PRICE_M2   PRICE  Cluster
# 1717     34.0     39.71  1350.0       29
# 1724     34.0     39.71  1350.0       29
# Cluster 30:
#       SURFACE  PRICE_M2     PRICE  Cluster
# 1750     32.0   12375.0  396000.0       30
# 2010     32.0   12375.0  396000.0       30
# 2129     32.0   12375.0  396000.0       30
# 2131     32.0   12375.0  396000.0       30
# Cluster 31:
#       SURFACE  PRICE_M2  PRICE  Cluster
# 1857     24.0     33.33  800.0       31
# 2104     24.0     33.33  800.0       31
# Cluster 32:
#       SURFACE  PRICE_M2      PRICE  Cluster
# 1903    102.0  11764.71  1200000.0       32
# 1905    102.0  11764.71  1200000.0       32

# %%
#
data_apar_no_ex_grp = data_apar_no_ex[['SURFACE','PRICE_M2','PRICE']]
data_apar_no_ex_grp = data_apar_no_ex_grp.dropna()

# Perform DBSCAN clustering
from sklearn.cluster import DBSCAN

dbscan = DBSCAN(eps=1, min_samples=2)
data_apar_no_ex_grp['Cluster'] = dbscan.fit_predict(data_apar_no_ex_grp)

# Display the clusters
unique_clusters = data_apar_no_ex_grp['Cluster'].unique()
for cluster_num in unique_clusters:
    if cluster_num == -1:  # Cluster -1 represents noisy points
        continue
    cluster_data = data_apar_no_ex_grp[data_apar_no_ex_grp['Cluster'] == cluster_num]
    print(f'Cluster {cluster_num}:')
    print(cluster_data)
# Out:
# Cluster 0:
#       SURFACE  PRICE_M2      PRICE  Cluster
# 2       267.0  18614.23  4970000.0        0
# 1097    267.0  18614.23  4970000.0        0
# 1172    267.0  18614.23  4970000.0        0
# 1529    267.0  18614.23  4970000.0        0
# Cluster 1:
#       SURFACE  PRICE_M2      PRICE  Cluster
# 5      142.76   9946.76  1420000.0        1
# 1089   142.76   9946.76  1420000.0        1
# 1851   142.76   9946.76  1420000.0        1
# Cluster 2:
#       SURFACE  PRICE_M2     PRICE  Cluster
# 9        57.0   10000.0  570000.0        2
# 92       57.0   10000.0  570000.0        2
# 1910     57.0   10000.0  570000.0        2
# 1952     57.0   10000.0  570000.0        2
# Cluster 3:
#       SURFACE  PRICE_M2   PRICE  Cluster
# 11       46.0     27.59  1269.0        3
# 134      46.0     27.59  1269.0        3
# 538      46.0     27.59  1269.0        3
# 1668     46.0     27.59  1269.0        3
# Cluster 4:
#       SURFACE  PRICE_M2     PRICE  Cluster
#

#       SURFACE  PRICE_M2     PRICE  Cluster
# 48       71.0  11690.14  830000.0       17
# 969      71.0  11690.14  830000.0       17
# 975      71.0  11690.14  830000.0       17
# 2031     71.0  11690.14  830000.0       17
# Cluster 18:
#      SURFACE  PRICE_M2  PRICE  Cluster
# 62      13.0     54.69  711.0       18
# 152     13.0     54.69  711.0       18
# Cluster 19:
#       SURFACE  PRICE_M2   PRICE  Cluster
# 64       51.0     31.37  1600.0       19
# 664      51.0     31.37  1600.0       19
# 743      51.0     31.37  1600.0       19
# 1406     51.0     31.37  1600.0       19
# 1421     51.0     31.37  1600.0       19
# 1993     51.0     31.37  1600.0       19
# Cluster 20:
#       SURFACE  PRICE_M2   PRICE  Cluster
# 67       27.0     38.89  1050.0       20
# 1279     27.0     38.89  1050.0       20
# 1884     27.0     38.89  1050.0       20
# Cluster 21:
#       SURFACE  PRICE_M2     PRICE  Cluster
# 68       77.0   5779.22  445000.0       21
# 387      77.0   5779.22  445000.0       21
# 851      77.0   5779.22  445000.0       21
# 1163     77.0   5779.22  445000.0       21
# 1195     77.0   5779.22  445000.0       21
# 1198     77.0   5779.22  445000.0       21
# 2135     77.0   5779.22  445000.0       21
# Cluster 22:
#       SURFACE  PRICE_M2      PRICE  Cluster
# 70      174.0  10632.18  1850000.0       22
# 102     174.0  10632.18  1850000.0       22
# 291     174.0  10632.18  1850000.0       22
# 929     174.0  10632.18  1850000.0       22
# 1065    174.0  10632.18  1850000.0       22
# 1300    174.0  10632.18  1850000.0       22
# 1767    174.0  10632.18  1850000.0       22
# Cluster 23:
#       SURFACE  PRICE_M2     PRICE  Cluster
# 82      70.51  10622.61  749000.0       23
# 833     70.51  10622.61  749000.0       23
# 1854    70.51  10622.61  749000.0       23
# Cluster 24:
#       SURFACE  PRICE_M2     PRICE  Cluster
# 87      87.11  11077.95  965000.0       24
# 1072    87.11  11077.95  965000.0       24
# 1550    87.11  11077.95  965000.0       24
# Cluster 25:
#       SURFACE  PRICE_M2      PRICE  Cluster
# 88      554.0  10198.56  5650000.0       25
# 1157    554.0  10198.56  5650000.0       25
# Cluster 26:
#       SURFACE  PRICE_M2     PRICE  Cluster
# 89       52.0   7711.54  401000.0       26
# 485      52.0   7711.54  401000.0       26
# 1310     52.0   7711.54  401000.0       26
# Cluster 27:
#       SURFACE  PRICE_M2     PRICE  Cluster
# 95       67.9   9631.81  654000.0       27
# 725      67.9   9631.81  654000.0       27
# 1200     67.9   9631.81  654000.0       27
# Cluster 28:
#       SURFACE  PRICE_M2     PRICE  Cluster
# 97       39.0  10897.44  425000.0       28
# 1795     39.0  10897.44  425000.0       28
# Cluster 29:
#       SURFACE  PRICE_M2      PRICE  Cluster
# 98      100.0   10990.0  1099000.0       29
# 187     100.0   10990.0  1099000.0       29
# 217     100.0   10990.0  1099000.0       29
# 933     100.0   10990.0  1099000.0       29
# 1671    100.0   10990.0  1099000.0       29
# 2069    100.0   10990.0  1099000.0       29
# Cluster 30:
#       SURFACE  PRICE_M2     PRICE  Cluster
# 99       71.0   8845.07  628000.0       30
# 887      71.0   8845.07  628000.0       30
# 1741     71.0   8845.07  628000.0       30
# Cluster 31:
#       SURFACE  PRICE_M2     PRICE  Cluster
# 100      83.0   9638.55  800000.0       31
# 1709     83.0   9638.55  800000.0       31
# Cluster 32:
#       SURFACE  PRICE_M2     PRICE  Cluster
# 101      27.0  10370.37  280000.0       32
# 486      27.0  10370.37  280000.0       32
# 723      27.0  10370.37  280000.0       32
# 1144     27.0  10370.37  280000.0       32
# Cluster 33:
#       SURFACE  PRICE_M2     PRICE  Cluster
# 103      65.0  11923.08  775000.0       33
# 971      65.0  11923.08  775000.0       33
# 1649     65.0  11923.08  775000.0       33
# Cluster 34:
#       SURFACE  PRICE_M2     PRICE  Cluster
# 105      51.0   9215.69  470000.0       34
# 683      51.0   9215.69  470000.0       34
# 902      51.0   9215.69  470000.0       34
# 963      51.0   9215.69  470000.0       34
# 1188     51.0   9215.69  470000.0       34
# 2087     51.0   9215.69  470000.0       34
# Cluster 35:
#       SURFACE  PRICE_M2      PRICE  Cluster
#

#       SURFACE  PRICE_M2     PRICE  Cluster
# 231      72.0   10625.0  765000.0       72
# 663      72.0   10625.0  765000.0       72
# 1037     72.0   10625.0  765000.0       72
# 1413     72.0   10625.0  765000.0       72
# 1787     72.0   10625.0  765000.0       72
# 2123     72.0   10625.0  765000.0       72
# Cluster 73:
#       SURFACE  PRICE_M2     PRICE  Cluster
# 236      86.0   7674.42  660000.0       73
# 325      86.0   7674.42  660000.0       73
# 1254     86.0   7674.42  660000.0       73
# 1972     86.0   7674.42  660000.0       73
# Cluster 74:
#      SURFACE  PRICE_M2  PRICE  Cluster
# 243     32.0     30.94  990.0       74
# 555     32.0     30.94  990.0       74
# Cluster 75:
#      SURFACE  PRICE_M2     PRICE  Cluster
# 250    49.63   9671.57  480000.0       75
# 798    49.63   9671.57  480000.0       75
# 990    49.63   9671.57  480000.0       75
# Cluster 76:
#       SURFACE  PRICE_M2    PRICE  Cluster
# 253       9.0    6500.0  58500.0       76
# 254       9.0    6500.0  58500.0       76
# 257       9.0    6500.0  58500.0       76
# 1408      9.0    6500.0  58500.0       76
# Cluster 77:
#       SURFACE  PRICE_M2     PRICE  Cluster
# 255      32.0   10500.0  336000.0       77
# 436      32.0   10500.0  336000.0       77
# 1756     32.0   10500.0  336000.0       77
# 1768     32.0   10500.0  336000.0       77
# Cluster 78:
#       SURFACE  PRICE_M2   PRICE  Cluster
# 260      99.0      30.0  2970.0       78
# 1395     99.0      30.0  2970.0       78
# 2045     99.0      30.0  2970.0       78
# Cluster 79:
#      SURFACE  PRICE_M2   PRICE  Cluster
# 264     70.0     38.86  2720.0       79
# 569     70.0     38.86  2720.0       79
# Cluster 80:
#       SURFACE  PRICE_M2     PRICE  Cluster
# 268      33.0   8484.85  280000.0       80
# 1145     33.0   8484.85  280000.0       80
# 1334     33.0   8484.85  280000.0       80
# 1667     33.0   8484.85  280000.0       80
# Cluster 81:
#      SURFACE  PRICE_M2     PRICE  Cluster
# 269     49.3   9736.31  480000.0       81
# 423     49.3   9736.31  480000.0       81
# Cluster 82:
#       SURFACE  PRICE_M2   PRICE  Cluster
# 270      59.0     30.51  1800.0       82
# 462      59.0     30.51  1800.0       82
# 570      59.0     30.51  1800.0       82
# 580      59.0     30.51  1800.0       82
# 895      59.0     30.51  1800.0       82
# 2149     59.0     30.51  1800.0       82
# Cluster 83:
#      SURFACE  PRICE_M2   PRICE  Cluster
# 275    68.00     27.94  1900.0       83
# 733    67.61     28.10  1900.0       83
# 808    67.00     28.36  1900.0       83
# Cluster 84:
#      SURFACE  PRICE_M2   PRICE  Cluster
# 278     44.0     32.95  1450.0       84
# 919     44.0     32.95  1450.0       84
# Cluster 85:
#       SURFACE  PRICE_M2  PRICE  Cluster
# 280     25.38     36.84  935.0       85
# 939     25.38     36.84  935.0       85
# 1257    25.00     37.40  935.0       85
# 1571    25.00     37.40  935.0       85
# Cluster 86:
#      SURFACE  PRICE_M2     PRICE  Cluster
# 283     72.0  11527.78  830000.0       86
# 521     72.0  11527.78  830000.0       86
# 560     72.0  11527.78  830000.0       86
# Cluster 87:
#       SURFACE  PRICE_M2     PRICE  Cluster
# 285     48.74   9212.15  449000.0       87
# 496     48.74   9212.15  449000.0       87
# 1141    48.74   9212.15  449000.0       87
# 1196    48.74   9212.15  449000.0       87
# 1651    48.74   9212.15  449000.0       87
# Cluster 88:
#       SURFACE  PRICE_M2     PRICE  Cluster
# 290      53.0   9339.62  495000.0       88
# 1788     53.0   9339.62  495000.0       88
# Cluster 89:
#       SURFACE  PRICE_M2  PRICE  Cluster
# 294      17.0      50.0  850.0       89
# 2110     17.0      50.0  850.0       89
# Cluster 90:
#       SURFACE  PRICE_M2   PRICE  Cluster
# 295      45.0     25.56  1150.0       90
# 1324     45.0     25.56  1150.0       90
# Cluster 91:
#       SURFACE  PRICE_M2     PRICE  Cluster
# 298      51.0    8254.9  421000.0       91
# 1076     51.0    8254.9  421000.0       91
# 1326     51.0    8254.9  421000.0       91
# 2059     51.0    8254.9  421000.0       91
# Cluster 92:
#       SURFACE  PRICE_M2   PRICE  Cluster
#

#       SURFACE  PRICE_M2     PRICE  Cluster
# 647      68.0  10985.29  747000.0      168
# 1293     68.0  10985.29  747000.0      168
# Cluster 169:
#       SURFACE  PRICE_M2   PRICE  Cluster
# 649      71.0     26.06  1850.0      169
# 885      71.0     26.06  1850.0      169
# 1598     71.0     26.06  1850.0      169
# 2046     71.0     26.06  1850.0      169
# Cluster 170:
#       SURFACE  PRICE_M2   PRICE  Cluster
# 656     43.05     32.87  1415.0      170
# 1046    43.00     32.91  1415.0      170
# Cluster 171:
#       SURFACE  PRICE_M2     PRICE  Cluster
# 658      35.0   8571.43  300000.0      171
# 1074     35.0   8571.43  300000.0      171
# 1302     35.0   8571.43  300000.0      171
# 1430     35.0   8571.43  300000.0      171
# 1441     35.0   8571.43  300000.0      171
# Cluster 172:
#       SURFACE  PRICE_M2     PRICE  Cluster
# 665      47.0   9574.47  450000.0      172
# 1567     47.0   9574.47  450000.0      172
# 1890     47.0   9574.47  450000.0      172
# Cluster 173:
#       SURFACE  PRICE_M2     PRICE  Cluster
# 666      49.0    7510.2  368000.0      173
# 720      49.0    7510.2  368000.0      173
# 1232     49.0    7510.2  368000.0      173
# Cluster 174:
#       SURFACE  PRICE_M2  PRICE  Cluster
# 667     25.00     35.60  890.0      174
# 1255    25.00     35.60  890.0      174
# 1442    25.58     34.79  890.0      174
# 1953    25.58     34.79  890.0      174
# Cluster 175:
#       SURFACE  PRICE_M2   PRICE  Cluster
# 670      52.0     29.81  1550.0      175
# 878      52.0     29.81  1550.0      175
# 2052     52.0     29.81  1550.0      175
# Cluster 176:
#      SURFACE  PRICE_M2     PRICE  Cluster
# 674     80.0   10612.5  849000.0      176
# 695     80.0   10612.5  849000.0      176
# Cluster 177:
#       SURFACE  PRICE_M2    PRICE  Cluster
# 679     53.00     26.96  1429.00      177
# 1594    53.22     26.85  1429.00      177
# 1597    53.22     26.85  1428.77      177
# 1982    53.00     26.96  1429.00      177
# Cluster 178:
#       SURFACE  PRICE_M2     PRICE  Cluster
# 684      45.0  10111.13  455001.0      178
# 1173     45.0  10111.13  455001.0      178
# Cluster 179:
#       SURFACE  PRICE_M2     PRICE  Cluster
# 694      63.0   8650.79  545000.0      179
# 1796     63.0   8650.79  545000.0      179
# 1803     63.0   8650.79  545000.0      179
# 1819     63.0   8650.79  545000.0      179
# Cluster 180:
#       SURFACE  PRICE_M2     PRICE  Cluster
# 699      50.0    9400.0  470000.0      180
# 1901     50.0    9400.0  470000.0      180
# Cluster 181:
#       SURFACE  PRICE_M2      PRICE  Cluster
# 717     128.0  10078.13  1290000.0      181
# 980     128.0  10078.13  1290000.0      181
# 1684    128.0  10078.13  1290000.0      181
# Cluster 182:
#       SURFACE  PRICE_M2   PRICE  Cluster
# 724     182.0      25.1  4568.0      182
# 1355    182.0      25.1  4568.0      182
# 1856    182.0      25.1  4568.0      182
# 2079    182.0      25.1  4568.0      182
# 2085    182.0      25.1  4568.0      182
# Cluster 183:
#       SURFACE  PRICE_M2      PRICE  Cluster
# 731     92.66  12626.81  1170000.0      183
# 1218    92.66  12626.81  1170000.0      183
# Cluster 184:
#       SURFACE  PRICE_M2     PRICE  Cluster
# 762      49.0  10183.67  499000.0      184
# 763      49.0  10183.67  499000.0      184
# 1517     49.0  10183.67  499000.0      184
# Cluster 185:
#       SURFACE  PRICE_M2     PRICE  Cluster
# 766      21.0  12380.95  260000.0      185
# 1158     21.0  12380.95  260000.0      185
# 1228     21.0  12380.95  260000.0      185
# 1429     21.0  12380.95  260000.0      185
# Cluster 186:
#       SURFACE  PRICE_M2   PRICE  Cluster
# 770      36.0     33.33  1200.0      186
# 1604     36.0     33.33  1200.0      186
# 1809     36.0     33.33  1200.0      186
# Cluster 187:
#      SURFACE  PRICE_M2   PRICE  Cluster
# 773     33.0     36.06  1190.0      187
# 775     33.0     36.06  1190.0      187
# Cluster 188:
#       SURFACE  PRICE_M2     PRICE  Cluster
# 776      27.0   9814.81  265000.0      188
# 1605     27.0   9814.81  265000.0      188
# 1696     27.0   9814.81  265000.0      188
# 1873     27.0   9814.81  265000.0      188
# Cluster 189:
#       SURFACE  PRICE_M2  PRICE  Cluster
# 779      20.0      47.5  950.0      189
# 1348     20.0      47.5  950.0      189
# Cluster 190:
#       SURFACE  PRICE_M2     PRICE  Cluster
# 785      64.0  10781.25  690000.0      190
# 1947     64.0  10781.25  690000.0      190
# 2025     64.0  10781.25  690000.0      190
# Cluster 191:
#       SURFACE  PRICE_M2     PRICE  Cluster
# 787      77.3  12289.78  950000.0      191
# 1128     77.3  12289.78  950000.0      191
# Cluster 192:
#       SURFACE  PRICE_M2     PRICE  Cluster
# 797      44.0   7272.73  320000.0      192
# 1110     44.0   7272.73  320000.0      192
# Cluster 193:
#       SURFACE  PRICE_M2   PRICE  Cluster
# 809     56.00     25.89  1450.0      193
# 1291    56.53     25.65  1450.0      193
# Cluster 194:
#       SURFACE  PRICE_M2     PRICE  Cluster
# 812     87.11  11307.54  985000.0      194
# 848     87.11  11307.54  985000.0      194
# 1073    87.11  11307.54  985000.0      194
# Cluster 195:
#       SURFACE  PRICE_M2     PRICE  Cluster
# 856      65.0   8446.15  549000.0      195
# 1174     65.0   8446.15  549000.0      195
# 1181     65.0   8446.15  549000.0      195
# 1959     65.0   8446.15  549000.0      195
# Cluster 196:
#       SURFACE  PRICE_M2  PRICE  Cluster
# 892      18.0     36.67  660.0      196
# 894      18.3     36.07  660.0      196
# 1494     18.0     36.67  660.0      196
# Cluster 197:
#       SURFACE  PRICE_M2     PRICE  Cluster
# 898      50.0    9980.0  499000.0      197
# 1794     50.0    9980.0  499000.0      197
# Cluster 198:
#       SURFACE  PRICE_M2   PRICE  Cluster
# 904     42.82     31.43  1346.0      198
# 1889    42.82     31.43  1346.0      198
# 1899    43.00     31.30  1346.0      198
# Cluster 199:
#      SURFACE  PRICE_M2     PRICE  Cluster
# 915     72.0  10486.11  755000.0      199
# 978     72.0  10486.11  755000.0      199
# Cluster 200:
#       SURFACE  PRICE_M2     PRICE  Cluster
# 926      54.0   8787.04  474500.0      200
# 983      54.0   8787.04  474500.0      200
# 1016     54.0   8787.04  474500.0      200
# 1398     54.0   8787.04  474500.0      200
# 1432     54.0   8787.04  474500.0      200
# 1583     54.0   8787.04  474500.0      200
# Cluster 201:
#      SURFACE  PRICE_M2     PRICE  Cluster
# 928    56.68  14587.16  826800.0      201
# 950    56.68  14587.16  826800.0      201
# Cluster 202:
#       SURFACE  PRICE_M2     PRICE  Cluster
# 935      75.0   9733.33  730000.0      202
# 1976     75.0   9733.33  730000.0      202
# Cluster 203:
#       SURFACE  PRICE_M2     PRICE  Cluster
# 938      52.0  10673.08  555000.0      203
# 1387     52.0  10673.08  555000.0      203
# 1577     52.0  10673.08  555000.0      203
# 2113     52.0  10673.08  555000.0      203
# Cluster 204:
#       SURFACE  PRICE_M2     PRICE  Cluster
# 940      12.0   9916.67  119000.0      204
# 1965     12.0   9916.67  119000.0      204
# Cluster 205:
#       SURFACE  PRICE_M2   PRICE  Cluster
# 956     26.92     48.29  1300.0      205
# 961     27.00     48.15  1300.0      205
# 1286    27.00     48.15  1300.0      205
# 1443    27.00     48.15  1300.0      205
# 1610    27.00     48.15  1300.0      205
# 2035    26.92     48.29  1300.0      205
# Cluster 206:
#       SURFACE  PRICE_M2  PRICE  Cluster
# 972      24.0     37.88  909.0      206
# 1375     24.0     37.88  909.0      206
# 1402     24.0     37.88  909.0      206
# Cluster 207:
#       SURFACE  PRICE_M2   PRICE  Cluster
# 973     77.88     30.82  2400.0      207
# 1653    77.88     30.82  2400.0      207
# Cluster 208:
#       SURFACE  PRICE_M2     PRICE  Cluster
# 977      45.0   8222.22  370000.0      208
# 1146     45.0   8222.22  370000.0      208
# 1170     45.0   8222.22  370000.0      208
# 1527     45.0   8222.22  370000.0      208
# Cluster 209:
#       SURFACE  PRICE_M2     PRICE  Cluster
# 981      66.0   8918.18  588600.0      209
# 1147     66.0   8918.18  588600.0      209
# 1422     66.0   8918.18  588600.0      209
# 1559     66.0   8918.18  588600.0      209
# Cluster 210:
#       SURFACE  PRICE_M2     PRICE  Cluster
# 985     14.45   10034.6  145000.0      210
# 1954    14.45   10034.6  145000.0      210
# Cluster 211:
#       SURFACE  PRICE_M2      PRICE  Cluster
#

#       SURFACE  PRICE_M2  PRICE  Cluster
# 1271     31.0     29.52  915.0      236
# 1313     31.0     29.52  915.0      236
# Cluster 237:
#       SURFACE  PRICE_M2   PRICE  Cluster
# 1277    45.56     27.96  1274.0      237
# 1886    45.56     27.96  1274.0      237
# Cluster 238:
#       SURFACE  PRICE_M2     PRICE  Cluster
# 1296     64.0   8421.88  539000.0      238
# 1607     64.0   8421.88  539000.0      238
# 2009     64.0   8421.88  539000.0      238
# Cluster 239:
#       SURFACE  PRICE_M2     PRICE  Cluster
# 1297     57.0   6052.63  345000.0      239
# 2018     57.0   6052.63  345000.0      239
# 2027     57.0   6052.63  345000.0      239
# Cluster 240:
#       SURFACE  PRICE_M2     PRICE  Cluster
# 1317     97.0  10257.73  995000.0      240
# 2065     97.0  10257.73  995000.0      240
# Cluster 241:
#       SURFACE  PRICE_M2  PRICE  Cluster
# 1357     30.0     29.67  890.0      241
# 1715     30.0     29.67  890.0      241
# Cluster 242:
#       SURFACE  PRICE_M2     PRICE  Cluster
# 1372    65.46  10999.08  720000.0      242
# 1643    65.46  10999.08  720000.0      242
# Cluster 243:
#       SURFACE  PRICE_M2  PRICE  Cluster
# 1438     23.0     34.57  795.0      243
# 1739     23.0     34.57  795.0      243
# 1813     23.0     34.57  795.0      243
# 1949     23.0     34.57  795.0      243
# Cluster 244:
#       SURFACE  PRICE_M2  PRICE  Cluster
# 1460     11.0     68.18  750.0      244
# 1929     11.0     68.18  750.0      244
# Cluster 245:
#       SURFACE  PRICE_M2      PRICE  Cluster
# 1501    215.0   9279.07  1995000.0      245
# 1832    215.0   9279.07  1995000.0      245
# Cluster 246:
#       SURFACE  PRICE_M2     PRICE  Cluster
# 1543     45.0  10111.11  455000.0      246
# 1919     45.0  10111.11  455000.0      246
# Cluster 247:
#       SURFACE  PRICE_M2   PRICE  Cluster
# 1563     72.0     31.81  2290.0      247
# 1917     72.0     31.81  2290.0      247
# Cluster 248:
#       SURFACE  PRICE_M2  PRICE  Cluster
# 1570     21.0     37.62  790.0      248
# 1974     21.0     37.62  790.0      248
# Cluster 249:
#       SURFACE  PRICE_M2   PRICE  Cluster
# 1590     68.0     27.21  1850.0      249
# 1975     68.0     27.21  1850.0      249
# Cluster 250:
#       SURFACE  PRICE_M2     PRICE  Cluster
# 1624     58.0  11534.48  669000.0      250
# 1940     58.0  11534.48  669000.0      250
# Cluster 251:
#       SURFACE  PRICE_M2     PRICE  Cluster
# 1625     85.0  11235.29  955000.0      251
# 1945     85.0  11235.29  955000.0      251
# Cluster 252:
#       SURFACE  PRICE_M2      PRICE  Cluster
# 1626    110.0  11754.55  1293000.0      252
# 1944    110.0  11754.55  1293000.0      252
# Cluster 253:
#       SURFACE  PRICE_M2     PRICE  Cluster
# 1666     43.0    8581.4  369000.0      253
# 2084     43.0    8581.4  369000.0      253
# Cluster 254:
#       SURFACE  PRICE_M2     PRICE  Cluster
# 1674     72.6  10399.45  755000.0      254
# 2062     72.6  10399.45  755000.0      254
# Cluster 255:
#       SURFACE  PRICE_M2     PRICE  Cluster
# 1693    112.0   5732.14  642000.0      255
# 1846    112.0   5732.14  642000.0      255
# Cluster 256:
#       SURFACE  PRICE_M2  PRICE  Cluster
# 1716     22.0     34.09  750.0      256
# 1826     22.0     34.09  750.0      256
# Cluster 257:
#       SURFACE  PRICE_M2     PRICE  Cluster
# 1774     67.0  10731.34  719000.0      257
# 2161     67.0  10731.34  719000.0      257
# Cluster 258:
#       SURFACE  PRICE_M2     PRICE  Cluster
# 1799     21.0  10476.19  220000.0      258
# 1964     21.0  10476.19  220000.0      258
# Cluster 259:
#       SURFACE  PRICE_M2     PRICE  Cluster
# 1811     34.0   7794.12  265000.0      259
# 1853     34.0   7794.12  265000.0      259
# 1892     34.0   7794.12  265000.0      259
# 1966     34.0   7794.12  265000.0      259
# Cluster 260:
#       SURFACE  PRICE_M2    PRICE  Cluster
# 1824     31.0     32.58  1010.00      260
# 2133     31.0     32.58  1010.00      260
# 2157     31.0     32.57  1009.65      260
# 2160     31.0     32.58  1010.00      260

# %% [markdown]
# Enfin on a regrouper les annonces parfaitement !
